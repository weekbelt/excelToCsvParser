# %%
import pandas as pd
from br import br_staffer, br_department

pd.set_option('display.max_columns', 20)


boryeong_branch_id = '0dbf43a0-a168-11e9-a893-49ac915e00a7'

all_user_data_file_name = 'br/data/allUserData_20210118092328 (1).xls'
department_data_file_name = 'br/data/stafferName.xlsx'

sh_br_department = pd.read_excel(io=all_user_data_file_name, sheet_name=0)
sh_br = pd.read_excel(io=all_user_data_file_name, sheet_name=1, converters={
        '회사전화': str, '조직코드': str, 'SADN1': str})
sh_match_department_staffer = pd.read_excel(io=department_data_file_name, sheet_name=0, converters={
        'STATION': str})

# 조직 정보 데이터 전처리
d_df = br_department.processDepartmentDataFrame(sh_br_department)

# 전체 사용자 정보 데이터 전처리
all_user_data_df = br_staffer.processAllUserData(sh_br)

# 직원 명부 데이터 전처리
pb_df = br_staffer.processDepartmentDataFrame(sh_match_department_staffer)

# 전체 사용자 정보와 조직 정보를 left outer로 merge
d_all_user_merged_df = all_user_data_df.merge(d_df, how='left', on='조직코드')

d_all_user_merged_df.info()

d_all_user_merged_df["이름"] = d_all_user_merged_df["이름_x"]
d_all_user_merged_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1483 entries, 0 to 1482
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조직코드    1483 non-null   object
#  1   이름_x    1483 non-null   object
#  2   회사명     1462 non-null   object
#  3   직급      1469 non-null   object
#  4   직책      1472 non-null   object
#  5   회사전화    1405 non-null   object
#  6   팩스번호    1288 non-null   object
#  7   담당업무    1392 non-null   object
#  8   SADN1   1201 non-null   object
#  9   상위코드    1473 non-null   object
#  10  이름_y    1473 non-null   object
# dtypes: object(11)
# memory usage: 139.0+ KB
#          조직코드 이름_x   회사명   직급      직책        회사전화          팩스번호  \
# 0      1.1.13  권승현   NaN  NaN     시의원        4009           NaN
# 1       1.1.1  김동일   NaN   시장      시장        3000           NaN
# 2      1.1.13  김정훈   NaN  NaN     시의원        4005           NaN
# 3      1.1.13  김충호   NaN  NaN     시의원        4010           NaN
# 4      1.1.13  김홍기   NaN  NaN     시의원        4001           NaN
# ...       ...  ...   ...  ...     ...         ...           ...
# 1478  1.1.8.4  박충신  보령시청   팀장  지방시설주사  0419306702  041-930-6709
# 1479   1.1.23  백남규  보령시청   팀장  지방농업주사  0419304792  041-930-4799
# 1480  1.1.5.1  박재민  보령시청  주무관     공무직         NaN           NaN
# 1481  1.1.8.1  양선민  보령시청  주무관     공무직  0419303033  041-930-6509
# 1482  1.1.4.4  손재숙  보령시청  주무관     공무직         NaN  041-930-3830
#
#                                                    담당업무 SADN1   상위코드    이름_y  \
# 0                                                   NaN  4009    1.1      의회
# 1                                                   NaN  5101    1.1     시장실
# 2                                                   NaN  4005    1.1      의회
# 3                                                   NaN  4010    1.1      의회
# 4                                                   NaN   NaN    1.1      의회
# ...                                                 ...   ...    ...     ...
# 1478  국도77호개통팀@@@국도77호개통팀 업무 총괄, 국도77호개통 대비 종합대책 사업 ...  6702  1.1.8   미래사업과
# 1479                        민원팀@@@ 가족관계등록, 결격사유조회, 인구동태  4792    1.1  미산면사무소
# 1480                                                NaN   NaN  1.1.5   자치행정과
# 1481                                     해양수산관광국장실 업무지원  3033  1.1.8   해양정책과
# 1482                                  교통지도팀@@@ 주,정차단속업무   NaN    NaN     NaN
#
#        이름
# 0     권승현
# 1     김동일
# 2     김정훈
# 3     김충호
# 4     김홍기
# ...   ...
# 1478  박충신
# 1479  백남규
# 1480  박재민
# 1481  양선민
# 1482  손재숙
#
# [1483 rows x 12 columns]
